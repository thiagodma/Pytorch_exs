# %%
# !wget -O data.zip "https://storage.googleapis.com/kaggle-data-sets/44109/78156/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1589918979&Signature=oOJ6FnnAn37CKLuFVFo5uCJ8bn2W3fMorVfIxrmKyVUwyhY11ieaFWWOZfO20cvXFsGEz278b1ny6ozhH5ud27qInmTfoxkntemUGfIFPDruYUvHTa1%2BEBDrUbwOu2kDP2PTWlUu%2FqiQ%2BIMgWtiFcQRnYyntmv7rArWEQkJiK4EEKRUG5f0mVvjfha8BZKSJg0kcjdXKUwyyB6fqyXgRZMPZLhfBR54Hz5n9eWRsCLLCjsbvKZSbjWemk8rebzBCCNBp7%2BQRdtr2ORwh%2FZElApGISTHtc5blxo9SdSIKJTNeypIFGBIrwUkeqZbvxozEsMEvRFpHilR3tL9u1M%2FQsg%3D%3D&response-content-disposition=attachment%3B+filename%3Dutkface-new.zip"
# !unzip data.zip

# %% [markdown]
# # 1. Reading the data

# %%
from fastai import *
from fastai.vision import *
from fastai.layers import MSELossFlat, CrossEntropyFlat
from torchvision import transforms
import warnings
warnings.filterwarnings("ignore")

# %%
files_train = get_image_files("utkface_aligned_cropped/UTKFace")
files_valid = get_image_files("utkface_aligned_cropped/crop_part1")

# %%
len(files_train), len(files_valid)
# Out:
# (23708, 9780)

# %%
df_train = pd.DataFrame(files_train,columns=["name"])
df_train.name = df_train.name.apply(str)
df_train["label"] = df_train.name.apply(lambda x: re.findall(r"\d{1,3}_\d_\d",x)[0])
df_train["label"] = df_train.label.apply(lambda x: re.sub("_"," ", x))
df_train["age"] = df_train.label.apply(lambda x: int(x.split(" ")[0]))
df_train["gender"] = df_train.label.apply(lambda x: int(x.split(" ")[1]))
df_train["ethnicity"] = df_train.label.apply(lambda x: int(x.split(" ")[2]))

# %%
df_valid = pd.DataFrame(files_valid,columns=["name"])
df_valid.name = df_valid.name.apply(str)
df_valid["label"] = df_valid.name.apply(lambda x: re.findall(r"\d{1,3}_\d_\d",x)[0])
df_valid["label"] = df_valid.label.apply(lambda x: re.sub("_"," ", x))
df_valid["age"] = df_valid.label.apply(lambda x: int(x.split(" ")[0]))
df_valid["gender"] = df_valid.label.apply(lambda x: int(x.split(" ")[1]))
df_valid["ethnicity"] = df_valid.label.apply(lambda x: int(x.split(" ")[2]))

# %%
df_train.head()
# Out:
#                                                 name   label  ...  gender  ethnicity
# 0  utkface_aligned_cropped/UTKFace/35_1_3_2017011...  35 1 3  ...       1          3
# 1  utkface_aligned_cropped/UTKFace/27_0_0_2017010...  27 0 0  ...       0          0
# 2  utkface_aligned_cropped/UTKFace/27_0_2_2017011...  27 0 2  ...       0          2
# 3  utkface_aligned_cropped/UTKFace/1_0_0_20161219...   1 0 0  ...       0          0
# 4  utkface_aligned_cropped/UTKFace/30_0_0_2017011...  30 0 0  ...       0          0
#
# [5 rows x 5 columns]

# %%
df_valid.head()
# Out:
#                                                 name   label  ...  gender  ethnicity
# 0  utkface_aligned_cropped/crop_part1/27_0_0_2017...  27 0 0  ...       0          0
# 1  utkface_aligned_cropped/crop_part1/1_0_0_20161...   1 0 0  ...       0          0
# 2  utkface_aligned_cropped/crop_part1/45_0_0_2017...  45 0 0  ...       0          0
# 3  utkface_aligned_cropped/crop_part1/2_1_2_20161...   2 1 2  ...       1          2
# 4  utkface_aligned_cropped/crop_part1/44_1_2_2017...  44 1 2  ...       1          2
#
# [5 rows x 5 columns]

# %%
#checking distribution for ages
df_train.age.hist()
df_valid.age.hist()
plt.legend(["train","valid"]);

# %%
#should be only 0s and 1s
df_train.gender.unique(), df_valid.gender.unique()
# Out:
# (array([1, 0]), array([0, 1, 3]))

# %%
#checking the mislabeled image
open_image(df_valid[df_valid.gender == 3].name.iloc[0])
# Out:
# Image (3, 200, 200)

# %%
#fixing the label
idx = df_valid[df_valid.gender == 3].index
df_valid.loc[idx,"gender"] = 1 #1 means woman

# %%
#accuracy is a good metric fore gender
(df_train.gender.value_counts()).plot.barh()
plt.title("train");

# %%
(df_valid.gender.value_counts()).plot.barh()
plt.title("valid");

# %%
d = {0:"White",1:"Black",2:"Asian",3:"Indian",4:"Others"}
df_train.ethnicity.replace(d).value_counts().sort_index().plot.barh()
plt.title("train");

# %%
df_valid.ethnicity.replace(d).value_counts().sort_index().plot.barh()
plt.title("valid");

# %% [markdown]
# # 2. Creating the Datasets, Dataloaders and Databunch

# %%
class MultiTaskDataset(Dataset):
    def __init__(self,df, tfms, size=64):
        self.paths = list(df.name)
        self.labels = list(df.label)
        self.tfms = tfms
        self.size = size
        self.norm = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) #imagenet stats

    def __len__(self): return len(self.paths)

    def __getitem__(self,idx):
        #dealing with the image
        img = PIL.Image.open(self.paths[idx]).convert('RGB')
        img = Image(pil2tensor(img, dtype=np.float32).div_(255))
        img = img.apply_tfms(self.tfms, size = self.size)
        img = self.norm(img.data)

        #dealing with the labels
        labels = self.labels[idx].split(" ")
        age = torch.tensor(float(labels[0]), dtype=torch.float32)
        gender = torch.tensor(int(labels[1]), dtype=torch.int64)
        ethnicity = torch.tensor(int(labels[2]), dtype=torch.int64)
        
        return img.data, (age.log_()/4.75, gender, ethnicity)

    def show(self,idx):
        x,y = self.__getitem__(idx)
        age,gender,ethnicity = y
        stds = np.array([0.229, 0.224, 0.225])
        means = np.array([0.485, 0.456, 0.406])
        img = ((x.numpy().transpose((1,2,0))*stds + means)*255).astype(np.uint8)
        plt.imshow(img)
        plt.title("{} {} {}".format(int(age.mul_(4.75).exp_().item()), gender.item(), ethnicity.item()))

# %%
tfms = get_transforms()
train_ds = MultiTaskDataset(df_train, tfms[0], size=64)
valid_ds = MultiTaskDataset(df_valid, tfms[1], size=64)
train_dl = DataLoader(train_ds, batch_size=512, shuffle=True, num_workers=2)
valid_dl = DataLoader(valid_ds, batch_size=512, shuffle=True, num_workers=2)
data = DataBunch(train_dl, valid_dl)

# %%
train_ds.show(0)

# %%
valid_ds.show(0)

# %%
class MultiTaskModel(nn.Module):
    def __init__(self, arch,ps=0.5):
        super(MultiTaskModel,self).__init__()
        self.encoder = create_body(arch)
        self.fc1 = create_head(1024,1,ps=ps)
        self.fc2 = create_head(1024,2,ps=ps)
        self.fc3 = create_head(1024,5,ps=ps)

    def forward(self,x):

        x = self.encoder(x)
        age = torch.sigmoid(self.fc1(x))
        gender = self.fc2(x)
        ethnicity = self.fc3(x)

        return [age, gender, ethnicity]

# %%
class MultiTaskLossWrapper(nn.Module):
    def __init__(self, task_num):
        super(MultiTaskLossWrapper, self).__init__()
        self.task_num = task_num
        self.log_vars = nn.Parameter(torch.zeros((task_num)))

    def forward(self, preds, age, gender, ethnicity):

        mse, crossEntropy = MSELossFlat(), CrossEntropyFlat()
        
        sages = (age*4.75).exp_()
        idx1 = (sages <20) | ((sages > 40) & (sages <= 60))
        idx2 = sages > 60
        loss0 = mse(preds[0], age) + 2*mse(preds[0][idx1],age[idx1]) + 3*mse(preds[0][idx2],age[idx2]) #trying to account for the imbalance
        loss1 = crossEntropy(preds[1],gender)
        loss2 = crossEntropy(preds[2],ethnicity)

        precision0 = torch.exp(-self.log_vars[0])
        loss0 = precision0*loss0 + self.log_vars[0]

        precision1 = torch.exp(-self.log_vars[1])
        loss1 = precision1*loss1 + self.log_vars[1]

        precision2 = torch.exp(-self.log_vars[2])
        loss2 = precision2*loss2 + self.log_vars[2]
        
        return loss0+loss1+loss2

# %% [markdown]
# # 4. Defining Metrics, Learner and Training

# %%
def rmse_age(preds, age, gender, ethnicity): return root_mean_squared_error(preds[0],age)
def acc_gender(preds, age, gender, ethnicity): return accuracy(preds[1], gender)
def acc_ethnicity(preds, age, gender, ethnicity): return accuracy(preds[2], ethnicity)
metrics = [rmse_age, acc_gender, acc_ethnicity]

# %%
model = MultiTaskModel(models.resnet34, ps=0.25)

loss_func = MultiTaskLossWrapper(3).to(data.device) #just making sure the loss is on the gpu

learn = Learner(data, model, loss_func=loss_func, callback_fns=ShowGraph, metrics=metrics)

#spliting the model so that I can use discriminative learning rates
learn.split([learn.model.encoder[:6],
             learn.model.encoder[6:],
             nn.ModuleList([learn.model.fc1, learn.model.fc2, learn.model.fc3])]);

#first I'll train only the last layer group (the heads)
learn.freeze()

# %%
torch.cuda.get_device_name()
# Out:
# 'Tesla T4'

# %%
torch.cuda.get_device_properties(0)
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 01:10<02:21]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>rmse_age</th>
#       <th>acc_gender</th>
#       <th>acc_ethnicity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.185666</td>
#       <td>#na#</td>
#       <td>01:10</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='41' class='' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       87.23% [41/47 01:02<00:09 7.3391]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(15,max_lr=1e-2,
                    callbacks=[callbacks.SaveModelCallback(learn, every='improvement', monitor='valid_loss', name='stage-1')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>rmse_age</th>
#       <th>acc_gender</th>
#       <th>acc_ethnicity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2
# Better model found at epoch 13 with valid_loss value: 0.6120133399963379.
# Better model found at epoch 14 with valid_loss value: 0.6046926379203796.
# Better model found at epoch 15 with valid_loss value: 0.5927101969718933.
# Better model found at epoch 16 with valid_loss value: 0.584510326385498.
# Better model found at epoch 17 with valid_loss value: 0.5712535977363586.
# Better model found at epoch 18 with valid_loss value: 0.5534610152244568.
# Better model found at epoch 19 with valid_loss value: 0.5437634587287903.
# Better model found at epoch 20 with valid_loss value: 0.5262291431427002.
# Better model found at epoch 21 with valid_loss value: 0.5200204849243164.
# Better model found at epoch 22 with valid_loss value: 0.5047153830528259.
# Better model found at epoch 23 with valid_loss value: 0.49084773659706116.
# Better model found at epoch 24 with valid_loss value: 0.47527793049812317.
# Better model found at epoch 25 with valid_loss value: 0.46065232157707214.
# Better model found at epoch 26 with valid_loss value: 0.44356176257133484.
# Better model found at epoch 27 with valid_loss value: 0.4297466576099396.
# Better model found at epoch 28 with valid_loss value: 0.418386846780777.
# Better model found at epoch 29 with valid_loss value: 0.3996441960334778.
# Better model found at epoch 30 with valid_loss value: 0.3904213011264801.
# Better model found at epoch 31 with valid_loss value: 0.36607635021209717.
# Better model found at epoch 32 with valid_loss value: 0.35973092913627625.
# Better model found at epoch 33 with valid_loss value: 0.3406717777252197.
# Better model found at epoch 34 with valid_loss value: 0.330120712518692.
# Better model found at epoch 35 with valid_loss value: 0.3247886598110199.
# Better model found at epoch 36 with valid_loss value: 0.30846062302589417.
# Better model found at epoch 37 with valid_loss value: 0.2877773344516754.
# Better model found at epoch 38 with valid_loss value: 0.2848031222820282.
# Better model found at epoch 39 with valid_loss value: 0.2718218266963959.
# Better model found at epoch 40 with valid_loss value: 0.261342316865921.
# Better model found at epoch 41 with valid_loss value: 0.2498631477355957.
# Better model found at epoch 42 with valid_loss value: 0.2459011822938919.
# Better model found at epoch 43 with valid_loss value: 0.23962165415287018.
# Better model found at epoch 44 with valid_loss value: 0.22574490308761597.
# Better model found at epoch 46 with valid_loss value: 0.20927944779396057.
# Better model found at epoch 47 with valid_loss value: 0.1956385225057602.
# Better model found at epoch 48 with valid_loss value: 0.19400358200073242.
# Better model found at epoch 49 with valid_loss value: 0.18430408835411072.
# Better model found at epoch 50 with valid_loss value: 0.1808990240097046.
# Better model found at epoch 51 with valid_loss value: 0.17254534363746643.
# Better model found at epoch 52 with valid_loss value: 0.16852279007434845.
# Better model found at epoch 53 with valid_loss value: 0.16351793706417084.
# Better model found at epoch 54 with valid_loss value: 0.15300820767879486.
# Better model found at epoch 56 with valid_loss value: 0.1468019187450409.
# Better model found at epoch 57 with valid_loss value: 0.13817362487316132.
# Better model found at epoch 58 with valid_loss value: 0.13760273158550262.
# Better model found at epoch 59 with valid_loss value: 0.13666851818561554.
# Better model found at epoch 60 with valid_loss value: 0.12866899371147156.
# Better model found at epoch 61 with valid_loss value: 0.1236199289560318.
# Better model found at epoch 62 with valid_loss value: 0.1217164620757103.
# Better model found at epoch 63 with valid_loss value: 0.11884716898202896.
# Better model found at epoch 64 with valid_loss value: 0.11329454183578491.
# Better model found at epoch 65 with valid_loss value: 0.11198901385068893.
# Better model found at epoch 66 with valid_loss value: 0.1064436137676239.
# Better model found at epoch 67 with valid_loss value: 0.10394573211669922.
# Better model found at epoch 68 with valid_loss value: 0.09869511425495148.
# Better model found at epoch 69 with valid_loss value: 0.09818306565284729.
# Better model found at epoch 70 with valid_loss value: 0.09510555863380432.
# Better model found at epoch 72 with valid_loss value: 0.09374337643384933.
# Better model found at epoch 73 with valid_loss value: 0.0897306427359581.
# Better model found at epoch 74 with valid_loss value: 0.087640680372715.
# Better model found at epoch 75 with valid_loss value: 0.08566563576459885.
# Better model found at epoch 77 with valid_loss value: 0.08298619091510773.
# Better model found at epoch 78 with valid_loss value: 0.0824294313788414.
# Better model found at epoch 80 with valid_loss value: 0.08232458680868149.
# Better model found at epoch 81 with valid_loss value: 0.08020690083503723.
# Better model found at epoch 82 with valid_loss value: 0.0799451395869255.
# Better model found at epoch 83 with valid_loss value: 0.07783029973506927.
# Better model found at epoch 84 with valid_loss value: 0.07732375711202621.
# Better model found at epoch 85 with valid_loss value: 0.07587363570928574.
# Better model found at epoch 86 with valid_loss value: 0.07518130540847778.
# Better model found at epoch 87 with valid_loss value: 0.07443041354417801.
# Better model found at epoch 88 with valid_loss value: 0.07408461719751358.
# Better model found at epoch 91 with valid_loss value: 0.07288264483213425.
# Better model found at epoch 94 with valid_loss value: 0.07258371263742447.
# Better model found at epoch 95 with valid_loss value: 0.07248995453119278.
# Better model found at epoch 97 with valid_loss value: 0.07248532772064209.
# Better model found at epoch 99 with valid_loss value: 0.07194849848747253.

# %%
learn = learn.load("stage-2")

# %% [markdown]
# # 5. Using the model to inference

# %%
trained_model = learn.model.cpu()
torch.save(trained_model.state_dict(),"model_params_resnet34")

# %%
class AgenethPredictor():
    def __init__(self, model):
        self.model = model
        self.tfms = get_transforms()[1]
        self.norm = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) #imagenet stats
        self.gender = {0:"Male",1:"Female"}
        self.ethnicity = {0:"White",1:"Black",2:"Asian",3:"Indian",4:"Others"}

    def predict(self,x):
        #x is a PIL Image
        x = Image(pil2tensor(x, dtype=np.float32).div_(255))
        x = x.apply_tfms(self.tfms, size = 64)
        x = self.norm(x.data)
        preds = self.model(x.unsqueeze(0))
        age = int(torch.exp(preds[0]*4.75).item())
        gender = self.gender[torch.softmax(preds[1],1).argmax().item()]
        ethnicity = self.ethnicity[torch.softmax(preds[2],1).argmax().item()]
        return age, gender, ethnicity

# %%
ageneth_predictor = AgenethPredictor(trained_model)

# %%
img = PIL.Image.open(df_valid.name.iloc[100])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F2EE74B7D30>

# %%
df_valid.name.iloc[100]
# Out:
# 'utkface_aligned_cropped/crop_part1/37_0_0_20170104205628245.jpg.chip.jpg'

# %%
# %time ageneth_predictor.predict(img)
# Out:
# CPU times: user 54.6 ms, sys: 10.9 ms, total: 65.5 ms
# Wall time: 156 ms
# (45, 'Male', 'White')

# %%
img = PIL.Image.open(df_valid.name.iloc[1000])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F2EE7E70AC8>

# %%
df_valid.name.iloc[1000]
# Out:
# 'utkface_aligned_cropped/crop_part1/23_1_3_20170104223058543.jpg.chip.jpg'

# %%
# %time ageneth_predictor.predict(img)
# Out:
# CPU times: user 50.7 ms, sys: 0 ns, total: 50.7 ms
# Wall time: 55.5 ms
# (23, 'Female', 'Indian')

# %%
img = PIL.Image.open(df_valid.name.iloc[2000])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F2EE72E0FD0>

# %%
df_valid.name.iloc[2000]
# Out:
# 'utkface_aligned_cropped/crop_part1/4_1_2_20161219163346526.jpg.chip.jpg'

# %%
# %time ageneth_predictor.predict(img)
# Out:
# CPU times: user 42 ms, sys: 0 ns, total: 42 ms
# Wall time: 43.4 ms
# (3, 'Female', 'Asian')

# %%
img = PIL.Image.open(df_valid.name.iloc[50])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F2EE72E0240>

# %%
df_valid.name.iloc[50]
# Out:
# 'utkface_aligned_cropped/crop_part1/16_0_0_20170110232111509.jpg.chip.jpg'

# %%
# %time ageneth_predictor.predict(img)
# Out:
# CPU times: user 43 ms, sys: 0 ns, total: 43 ms
# Wall time: 43.5 ms
# (18, 'Male', 'White')

# %%
img = PIL.Image.open(df_valid.name.iloc[9000])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F2EE72E0780>

# %%
df_valid.name.iloc[9000]
# Out:
# 'utkface_aligned_cropped/crop_part1/65_0_0_20170111200004259.jpg.chip.jpg'

# %%
# %time ageneth_predictor.predict(img)
# Out:
# CPU times: user 41.3 ms, sys: 692 µs, total: 41.9 ms
# Wall time: 44.7 ms
# (64, 'Male', 'White')

# %%
img = PIL.Image.open(df_valid.name.iloc[-1])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F2EE7F7B748>

# %%
df_valid.name.iloc[-1]
# Out:
# 'utkface_aligned_cropped/crop_part1/34_0_4_20170105165000683.jpg.chip.jpg'

# %%
# %time ageneth_predictor.predict(img)
# Out:
# CPU times: user 53.5 ms, sys: 2.43 ms, total: 55.9 ms
# Wall time: 59.2 ms
# (38, 'Male', 'Others')

# %%
img = PIL.Image.open(df_valid.name.iloc[-100])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F2EE7F7BA20>

# %%
df_valid.name.iloc[-100]
# Out:
# 'utkface_aligned_cropped/crop_part1/53_1_0_20170110144754148.jpg.chip.jpg'

# %%
# %time ageneth_predictor.predict(img)
# Out:
# CPU times: user 43.3 ms, sys: 1.74 ms, total: 45 ms
# Wall time: 45.3 ms
# (25, 'Female', 'White')

# %%
img = PIL.Image.open(df_valid.name.iloc[-500])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F2EE710A860>

# %%
df_valid.name.iloc[-500]
# Out:
# 'utkface_aligned_cropped/crop_part1/26_1_0_20170103180946896.jpg.chip.jpg'

# %%
# %time ageneth_predictor.predict(img)
# Out:
# CPU times: user 40.6 ms, sys: 309 µs, total: 40.9 ms
# Wall time: 45.1 ms
# (47, 'Female', 'White')
